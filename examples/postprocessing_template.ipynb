# %% [markdown]
# # AerisLab Postprocessing Template
#
# Use this notebook to generate high-quality figures for your thesis.
# It uses the `plotly` engine for interactive exploration and static export.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
from pathlib import Path

# Add src to path
sys.path.append(str(Path("..").resolve() / "src"))

from aerislab.visualization import plotting
import plotly.io as pio

# Set default renderer
pio.renderers.default = "notebook_connected"

# %% [markdown]
# ## Load Simulation Data
# Point this to your simulation CSV file.

# %%
# Example path - replace with your actual data
csv_path = "output/simulation.csv"
body_name = "payload"

# %% [markdown]
# ## 3D Trajectory

# %%
fig = plotting.plot_trajectory_3d(csv_path, body_name, engine="plotly")
fig.show()
# fig.write_image("trajectory.pdf") # Uncomment to save for LaTeX

# %% [markdown]
# ## Kinematics

# %%
fig = plotting.plot_velocity_and_acceleration(csv_path, body_name, engine="plotly")
fig.show()

# %% [markdown]
# ## Forces

# %%
fig = plotting.plot_forces(csv_path, body_name, engine="plotly")
fig.show()
